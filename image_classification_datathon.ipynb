# %% [markdown]
# <a href="https://colab.research.google.com/github/websitecreatr99/datathon-image-classification/blob/main/image_classification_datathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c datathonindoml-2022
# Out:
# ...
# 100% 1.51G/1.51G [00:17<00:00, 122MB/s]
# 100% 1.51G/1.51G [00:17<00:00, 90.9MB/s]

# %%
# !ls
# Out:
# datathonindoml-2022.zip  drive	kaggle.json  sample_data

# %%
# extracting the compressed dataset
from zipfile import ZipFile

dataset = '/content/datathonindoml-2022.zip'

with ZipFile(dataset, 'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.image as mpimg
import os
import seaborn as sns
import cv2
# %matplotlib inline

# %%
df = pd.read_csv("train_labels.csv")

# %%
df.head()
# Out:
#    id  label
# 0   0      1
# 1   1     13
# 2   2     13
# 3   3     14
# 4   4      6

# %%
os.mkdir("images")
os.mkdir("images/l0")
os.mkdir("images/l1")
os.mkdir("images/l2")
os.mkdir("images/l3")
os.mkdir("images/l4")
os.mkdir("images/l5")
os.mkdir("images/l6")
os.mkdir("images/l7")
os.mkdir("images/l8")
os.mkdir("images/l9")
os.mkdir("images/l10")
os.mkdir("images/l11")
os.mkdir("images/l12")
os.mkdir("images/l13")
os.mkdir("images/l14")
os.mkdir("images/l15")

# %%
from tqdm import tqdm

original_folder = 'train/train/'
images_folder = 'images' 

# l0 = []
# l1 = []
# l2 = []
# l3 = []
# l4 = []
# l5 = []
# l6 = []
# l7 = []
# l8 = []
# l9 = []
# l10 = []
# l11 = []
# l12 = []
# l13 = []
# l14 = []
# l15 = []


for i in tqdm(range(16000)):
    try:
        a = os.listdir("train/train/")[i].split(".")[0]
        if ( a == str(df["id"][int(a)])) and df["label"][int(a)] == 0:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l0/"+filename
            img.save(newImgPath)
  
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 1:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l1/"+filename
            img.save(newImgPath)            
  
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 2:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l2/"+filename
            img.save(newImgPath)
              
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 3:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l3/"+filename
            img.save(newImgPath)
             
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 4:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l4/"+filename
            img.save(newImgPath)
 
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 5:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l5/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 6:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l6/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 7:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l7/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 8:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l8/"+filename
            img.save(newImgPath)
 
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 9:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l9/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 10:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l10/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 11:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l11/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 12:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l12/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 13:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l13/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 14:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l14/"+filename
            img.save(newImgPath)
            

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 15:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = images_folder+"/l15/"+filename
            img.save(newImgPath)
            
    except:
        continue
# Out:
# 100%|██████████| 16000/16000 [05:11<00:00, 51.39it/s]

# %%
os.mkdir("valid")
os.mkdir("valid/l0")
os.mkdir("valid/l1")
os.mkdir("valid/l2")
os.mkdir("valid/l3")
os.mkdir("valid/l4")
os.mkdir("valid/l5")
os.mkdir("valid/l6")
os.mkdir("valid/l7")
os.mkdir("valid/l8")
os.mkdir("valid/l9")
os.mkdir("valid/l10")
os.mkdir("valid/l11")
os.mkdir("valid/l12")
os.mkdir("valid/l13")
os.mkdir("valid/l14")
os.mkdir("valid/l15")

# %%
from tqdm import tqdm

original_folder = "train/train/"
validation = "valid"

for i in tqdm(range(500,1500)):
    try:
        a = os.listdir("train/train/")[i].split(".")[0]
        if ( a == str(df["id"][int(a)])) and df["label"][int(a)] == 0:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l0/"+filename
            img.save(newImgPath)
  
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 1:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l1/"+filename
            img.save(newImgPath)            
  
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 2:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l2/"+filename
            img.save(newImgPath)
              
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 3:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l3/"+filename
            img.save(newImgPath)
             
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 4:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l4/"+filename
            img.save(newImgPath)
 
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 5:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l5/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 6:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l6/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 7:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l7/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 8:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l8/"+filename
            img.save(newImgPath)
 
        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 9:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l9/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 10:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l10/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 11:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l11/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 12:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l12/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 13:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l13/"+filename
            img.save(newImgPath)

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 14:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l14/"+filename
            img.save(newImgPath)
            

        elif (a == str(df["id"][int(a)])) and df["label"][int(a)] == 15:
            filename = os.listdir(original_folder)[i]
            img_path = original_folder+filename
            img = Image.open(img_path)
            newImgPath = validation+"/l15/"+filename
            img.save(newImgPath)
            
    except:
        continue
# Out:
# 100%|██████████| 1000/1000 [00:19<00:00, 51.87it/s]

# %%
# import the libraries as shown below

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
#from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
#import matplotlib.pyplot as plt

# %%
resnet = ResNet50(input_shape=(224,224,3), weights='imagenet', include_top=False)
# don't train existing weights
for layer in resnet.layers:
    layer.trainable = False
# Out:
# ...
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
x = Flatten()(resnet.output)

# %%
prediction = Dense(16, activation='softmax')(x)

# create a model object
model = Model(inputs=resnet.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
# ...

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory('images',
                                                 target_size = (224, 224),
                                                 batch_size = 8,
                                                 class_mode = 'categorical')
# Out:
# Found 16000 images belonging to 16 classes.

# %%
test_set = test_datagen.flow_from_directory('valid',
                                            target_size = (224, 224),
                                            batch_size = 8,
                                            class_mode = 'categorical')
# Out:
# Found 1000 images belonging to 16 classes.

# %%
# fit the model
# Run the cell. It will take some time to execute
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=50,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# 2000/2000 [==============================] - 97s 42ms/step - loss: 5.6990 - accuracy: 0.3251 - val_loss: 4.1082 - val_accuracy: 0.4370
# Epoch 2/50
# 2000/2000 [==============================] - 84s 42ms/step - loss: 5.1168 - accuracy: 0.4207 - val_loss: 3.4376 - val_accuracy: 0.5150
# Epoch 3/50
# 2000/2000 [==============================] - 82s 41ms/step - loss: 4.8305 - accuracy: 0.4585 - val_loss: 5.9823 - val_accuracy: 0.5030
# Epoch 4/50
# 2000/2000 [==============================] - 81s 41ms/step - loss: 4.6792 - accuracy: 0.4842 - val_loss: 3.4343 - val_accuracy: 0.5270
# Epoch 5/50
# 2000/2000 [==============================] - 81s 41ms/step - loss: 4.5451 - accuracy: 0.5045 - val_loss: 2.6205 - val_accuracy: 0.6420
# Epoch 6/50
# ...
